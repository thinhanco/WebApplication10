-- %% [markdown]
-- # [dbo].[BaoCaoPhongs]

-- %%
USE [QuanLyKhachSan]
GO

-- %%
/****** Object:  Table [dbo].[BaoCaoPhongs]    Script Date: 03-04-2026 10:36:30 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BaoCaoPhongs](
	[MaBaoCao] [int] IDENTITY(1,1) NOT NULL,
	[SoPhong] [int] NULL,
	[NoiDungBaoCao] [nvarchar](max) NULL,
	[NgayBaoCao] [datetime] NULL,
	[TinhTrangSauQuanLy] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaBaoCao] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CaLams]

-- %%
/****** Object:  Table [dbo].[CaLams]    Script Date: 03-04-2026 10:36:30 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CaLams](
	[MaCa] [int] IDENTITY(1,1) NOT NULL,
	[TenCa] [nvarchar](50) NOT NULL,
	[GioBatDau] [time](7) NOT NULL,
	[GioKetThuc] [time](7) NOT NULL,
	[SoLuongToiDa] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[MaCa] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ChucVus]

-- %%
/****** Object:  Table [dbo].[ChucVus]    Script Date: 03-04-2026 10:36:30 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ChucVus](
	[MaChucVu] [int] IDENTITY(1,1) NOT NULL,
	[TenChucVu] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[MaChucVu] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DangKyCaLams]

-- %%
/****** Object:  Table [dbo].[DangKyCaLams]    Script Date: 03-04-2026 10:36:30 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DangKyCaLams](
	[MaDK] [int] IDENTITY(1,1) NOT NULL,
	[MaNV] [int] NULL,
	[MaCa] [int] NULL,
	[NgayLam] [date] NULL,
	[TrangThai] [nvarchar](50) NULL,
	[GhiChu] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaDK] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NhanViens]

-- %%
/****** Object:  Table [dbo].[NhanViens]    Script Date: 03-04-2026 10:36:30 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NhanViens](
	[MaNV] [int] IDENTITY(1,1) NOT NULL,
	[HoTen] [nvarchar](100) NULL,
	[MaChucVu] [int] NULL,
	[Email] [nvarchar](100) NULL,
	[SoDienThoai] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaNV] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Phongs]

-- %%
/****** Object:  Table [dbo].[Phongs]    Script Date: 03-04-2026 10:36:30 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Phongs](
	[SoPhong] [int] NOT NULL,
	[LoaiPhong] [nvarchar](50) NULL,
	[TrangThai] [nvarchar](50) NULL,
	[GiaPhong] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[SoPhong] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaiKhoans]

-- %%
/****** Object:  Table [dbo].[TaiKhoans]    Script Date: 03-04-2026 10:36:30 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaiKhoans](
	[TenDangNhap] [varchar](50) NOT NULL,
	[MatKhau] [varchar](50) NOT NULL,
	[MaNV] [int] NULL,
	[IsLocked] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[TenDangNhap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CaLams]

-- %%
SET IDENTITY_INSERT [dbo].[CaLams] ON 
INSERT [dbo].[CaLams] ([MaCa], [TenCa], [GioBatDau], [GioKetThuc], [SoLuongToiDa]) VALUES (1, N'Ca Sáng', CAST(N'06:00:00' AS Time), CAST(N'14:00:00' AS Time), 10)
INSERT [dbo].[CaLams] ([MaCa], [TenCa], [GioBatDau], [GioKetThuc], [SoLuongToiDa]) VALUES (2, N'Ca Chiều', CAST(N'14:00:00' AS Time), CAST(N'22:00:00' AS Time), 10)
INSERT [dbo].[CaLams] ([MaCa], [TenCa], [GioBatDau], [GioKetThuc], [SoLuongToiDa]) VALUES (3, N'Ca Tối', CAST(N'22:00:00' AS Time), CAST(N'06:00:00' AS Time), 10)
SET IDENTITY_INSERT [dbo].[CaLams] OFF
GO

-- %% [markdown]
-- # [dbo].[ChucVus]

-- %%
SET IDENTITY_INSERT [dbo].[ChucVus] ON 
INSERT [dbo].[ChucVus] ([MaChucVu], [TenChucVu]) VALUES (1, N'Admin')
INSERT [dbo].[ChucVus] ([MaChucVu], [TenChucVu]) VALUES (2, N'NhanVien')
SET IDENTITY_INSERT [dbo].[ChucVus] OFF
GO

-- %% [markdown]
-- # [dbo].[NhanViens]

-- %%
SET IDENTITY_INSERT [dbo].[NhanViens] ON 
INSERT [dbo].[NhanViens] ([MaNV], [HoTen], [MaChucVu], [Email], [SoDienThoai]) VALUES (1, N'Quản trị viên', 1, NULL, NULL)
INSERT [dbo].[NhanViens] ([MaNV], [HoTen], [MaChucVu], [Email], [SoDienThoai]) VALUES (2, N'Nguyễn Văn A', 2, NULL, NULL)
SET IDENTITY_INSERT [dbo].[NhanViens] OFF
GO

-- %% [markdown]
-- # [dbo].[Phongs]

-- %%
INSERT [dbo].[Phongs] ([SoPhong], [LoaiPhong], [TrangThai], [GiaPhong]) VALUES (101, N'Deluxe', N'Đang ở', 500000)
INSERT [dbo].[Phongs] ([SoPhong], [LoaiPhong], [TrangThai], [GiaPhong]) VALUES (102, N'Standard', N'Đang ở', 300000)
INSERT [dbo].[Phongs] ([SoPhong], [LoaiPhong], [TrangThai], [GiaPhong]) VALUES (103, N'Suite', N'Đang dọn', 1200000)
GO

-- %% [markdown]
-- # [dbo].[TaiKhoans]

-- %%
INSERT [dbo].[TaiKhoans] ([TenDangNhap], [MatKhau], [MaNV], [IsLocked]) VALUES (N'admin', N'123', 1, 0)
INSERT [dbo].[TaiKhoans] ([TenDangNhap], [MatKhau], [MaNV], [IsLocked]) VALUES (N'nhanvien', N'123', 2, 0)
GO

-- %% [markdown]
-- # [UQ__TaiKhoan__2725D70B80C39368]

-- %%
/****** Object:  Index [UQ__TaiKhoan__2725D70B80C39368]    Script Date: 03-04-2026 10:36:30 PM ******/
ALTER TABLE [dbo].[TaiKhoans] ADD UNIQUE NONCLUSTERED 
(
	[MaNV] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__BaoCaoPho__NgayB__4BAC3F29]

-- %%
ALTER TABLE [dbo].[BaoCaoPhongs] ADD  DEFAULT (getdate()) FOR [NgayBaoCao]
GO

-- %% [markdown]
-- # [DF__BaoCaoPho__TinhT__4CA06362]

-- %%
ALTER TABLE [dbo].[BaoCaoPhongs] ADD  DEFAULT (N'Đang chờ') FOR [TinhTrangSauQuanLy]
GO

-- %% [markdown]
-- # [DF__CaLams__SoLuongT__403A8C7D]

-- %%
ALTER TABLE [dbo].[CaLams] ADD  DEFAULT ((10)) FOR [SoLuongToiDa]
GO

-- %% [markdown]
-- # [DF__DangKyCaL__Trang__47DBAE45]

-- %%
ALTER TABLE [dbo].[DangKyCaLams] ADD  DEFAULT (N'Pending') FOR [TrangThai]
GO

-- %% [markdown]
-- # [DF__Phongs__TrangTha__4316F928]

-- %%
ALTER TABLE [dbo].[Phongs] ADD  DEFAULT (N'Trống') FOR [TrangThai]
GO

-- %% [markdown]
-- # [DF__TaiKhoans__IsLoc__5AEE82B9]

-- %%
ALTER TABLE [dbo].[TaiKhoans] ADD  DEFAULT ((0)) FOR [IsLocked]
GO

-- %% [markdown]
-- # [FK__BaoCaoPho__SoPho__4AB81AF0]

-- %%
ALTER TABLE [dbo].[BaoCaoPhongs]  WITH CHECK ADD FOREIGN KEY([SoPhong])
REFERENCES [dbo].[Phongs] ([SoPhong])
GO

-- %% [markdown]
-- # [FK__DangKyCaLa__MaCa__46E78A0C]

-- %%
ALTER TABLE [dbo].[DangKyCaLams]  WITH CHECK ADD FOREIGN KEY([MaCa])
REFERENCES [dbo].[CaLams] ([MaCa])
GO

-- %% [markdown]
-- # [FK__DangKyCaLa__MaNV__45F365D3]

-- %%
ALTER TABLE [dbo].[DangKyCaLams]  WITH CHECK ADD FOREIGN KEY([MaNV])
REFERENCES [dbo].[NhanViens] ([MaNV])
GO

-- %% [markdown]
-- # [FK__NhanVien__MaChuc__398D8EEE]

-- %%
ALTER TABLE [dbo].[NhanViens]  WITH CHECK ADD FOREIGN KEY([MaChucVu])
REFERENCES [dbo].[ChucVus] ([MaChucVu])
GO

-- %% [markdown]
-- # [FK__TaiKhoan__MaNV__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[TaiKhoans]  WITH CHECK ADD FOREIGN KEY([MaNV])
REFERENCES [dbo].[NhanViens] ([MaNV])
GO
