-- %% [markdown]
-- # [dbo].[danhmuc]

-- %%
USE [wf]
GO

-- %%
/****** Object:  Table [dbo].[danhmuc]    Script Date: 03-04-2026 10:26:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[danhmuc](
	[madanhmuc] [int] NOT NULL,
	[tendanhmuc] [nchar](10) NULL,
 CONSTRAINT [PK_danhmuc] PRIMARY KEY CLUSTERED 
(
	[madanhmuc] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sp]

-- %%
/****** Object:  Table [dbo].[sp]    Script Date: 03-04-2026 10:26:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sp](
	[ma] [int] NOT NULL,
	[ten] [nvarchar](50) NULL,
	[dongia] [int] NULL,
	[madanhmuc] [int] NULL,
 CONSTRAINT [PK_sp] PRIMARY KEY CLUSTERED 
(
	[ma] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[danhmuc]

-- %%
INSERT [dbo].[danhmuc] ([madanhmuc], [tendanhmuc]) VALUES (1, N'hangdientu')
INSERT [dbo].[danhmuc] ([madanhmuc], [tendanhmuc]) VALUES (2, N'hoachat   ')
INSERT [dbo].[danhmuc] ([madanhmuc], [tendanhmuc]) VALUES (3, N'hangchayno')
GO

-- %% [markdown]
-- # [dbo].[sp]

-- %%
INSERT [dbo].[sp] ([ma], [ten], [dongia], [madanhmuc]) VALUES (1, N'bongden', 50, 1)
INSERT [dbo].[sp] ([ma], [ten], [dongia], [madanhmuc]) VALUES (2, N'thuocdietmoi', 50, 2)
INSERT [dbo].[sp] ([ma], [ten], [dongia], [madanhmuc]) VALUES (3, N'thuockien', 35, 2)
INSERT [dbo].[sp] ([ma], [ten], [dongia], [madanhmuc]) VALUES (4, N'dentron', 32, 1)
INSERT [dbo].[sp] ([ma], [ten], [dongia], [madanhmuc]) VALUES (5, N'keocatsat', 45, 2)
INSERT [dbo].[sp] ([ma], [ten], [dongia], [madanhmuc]) VALUES (6, N'bongdenduong', 12, 1)
GO

-- %% [markdown]
-- # [FK_sp_danhmuc]

-- %%
ALTER TABLE [dbo].[sp]  WITH CHECK ADD  CONSTRAINT [FK_sp_danhmuc] FOREIGN KEY([madanhmuc])
REFERENCES [dbo].[danhmuc] ([madanhmuc])
GO
ALTER TABLE [dbo].[sp] CHECK CONSTRAINT [FK_sp_danhmuc]
GO
